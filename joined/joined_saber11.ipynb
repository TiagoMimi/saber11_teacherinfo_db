# %% [markdown]
# # Saber 11 test - Join
#     - Author: Santiago Avella. Git hub: https://github.com/TiagoMimi

# %%
import pandas as pd
from pathlib import Path
import warnings
warnings.filterwarnings("ignore")
# *Configure pandas to display all columns in DataFrame outputs*
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Load data

# %%
# Current working directory
script_path = Path.cwd()

# Find the project folder
project_path = script_path

while project_path.name != "saber11_db":
    project_path = project_path.parent

# The folder containing the TXT files
data_path = project_path / "data" / "source" / "saber11_results"

# List of TXT files
file_list = [
    data_path / "Examen_Saber_11_20151.txt",
    data_path / "Examen_Saber_11_20152.txt",
    data_path / "Examen_Saber_11_20161.txt",
    data_path / "Examen_Saber_11_20162.txt",
    data_path / "Examen_Saber_11_20171.txt",
    data_path / "Examen_Saber_11_20172.txt",
    data_path / "Examen_Saber_11_20181.txt",
    data_path / "Examen_Saber_11_20182.txt",
    data_path / "Examen_Saber_11_20191.txt",
    data_path / "Examen_Saber_11_20192.txt",
    data_path / "Examen_Saber_11_20201.txt",
    data_path / "Examen_Saber_11_20202.txt",
    data_path / "Examen_Saber_11_20211.txt",
    data_path / "Examen_Saber_11_20212.txt",
    data_path / "Examen_Saber_11_20221.txt",
    data_path / "Examen_Saber_11_20222.txt",
    data_path / "Examen_Saber_11_20231.txt",
    data_path / "Examen_Saber_11_20232.txt",
    data_path / "Examen_Saber_11_20241.txt",
    data_path / "Examen_Saber_11_20242.txt"
]

# Read all TXT files
dataframes = [
    pd.read_csv(file, sep=";")
    for file in file_list
]

# Concatenate all files
df_saber11 = pd.concat(
    dataframes,
    axis=0,
    ignore_index=True
)

# %%
df_saber11
# Out:
#          periodo  estu_consecutivo estu_estudiante estu_tipodocumento  \
# 0          20151  SB11201510000485      ESTUDIANTE                 CC
# 1          20151  SB11201510115564      ESTUDIANTE                 TI
# 2          20151  SB11201510097089      ESTUDIANTE                 TI
# 3          20151  SB11201510115560      ESTUDIANTE                 CC
# 4          20151  SB11201510002784      ESTUDIANTE                 TI
# ...          ...               ...             ...                ...
# 6665241    20242  SB11202430000016      INDIVIDUAL                 CC
# 6665242    20242  SB11202430041817      INDIVIDUAL                 TI
# 6665243    20242  SB11202430073368      INDIVIDUAL                 CC
# 6665244    20242  SB11202430051722      INDIVIDUAL                 CC
# 6665245    20242  SB11202430274808      INDIVIDUAL                 CC
#
#         cole_area_ubicacion cole_bilingue cole_calendario cole_caracter  \
# ...

# %% [markdown]
# ## Quality of the data

# %%
def dataframe_quality_function(dataframe):

    try:
        column_summary = []
        for col in dataframe.columns:                                      # *Iterate through the dataset columns*
            total_rows = len(dataframe)                                    # *Calculate the total number of rows*
            n_nulls = dataframe[col].isna().sum()                         # *Calculate the number of null values per column*
            percent_null = ((n_nulls / total_rows) * 100).round(2)        # *Calculate the percentage of null values*
            non_null = total_rows - n_nulls                               # *Calculate the number of non-null values*
            percent_non_null = ((non_null / total_rows) * 100).round(2)   # *Calculate the percentage of non-null values*
            dtype = dataframe[col].dtype                                   # *Get the data type of the column*
            column_summary.append({                                       # *Create the data quality summary for reporting or export*

                "Column_Name": col,
                "Data_Type": dtype,
                "Valid_Records": non_null,
                "Percentage_Valid_Records": percent_non_null,
                "Null_Records": n_nulls,
                "Percentage_Null_Records": percent_null
            })

        df_quality_summary = pd.DataFrame(column_summary)
        df_quality_summary.to_excel("saber11_dataframe_quality.xlsx")
        print("Excel completed")

        return df_quality_summary
    except Exception as e:
        print("Excel creation was not completed")

# %%
dataframe_quality_function(df_saber11)
# Out:
# Excel creation was not completed

# %% [markdown]
# ## Clean the data

# %% [markdown]
# ### only students

# %% [markdown]
# - In the estu_estudiante column, there are two types of records: Estudiante and Individual. This indicates whether the student was registered through a school (the first category) or registered individually (the second category).
# - Since our study focuses on schools as educational institutions and aims to examine the relationship between teacher characteristics and student outcomes, we will use only the records categorized as Estudiante.

# %%
df_saber11 = df_saber11[df_saber11["estu_estudiante"] == "ESTUDIANTE"]

# %% [markdown]
# ### Data Organization
#
# We will organize the information into three main categories:
#
# - **Student Information:** Variables describing the student's personal, academic, and demographic characteristics.
#
# - **School Information:** Variables related to the educational institution, such as school characteristics and location.
#
# - **Socioeconomic Information:** Variables describing the student's family background, socioeconomic conditions, and household characteristics.
#
# - **Student Results:** Variables related to the student's academic performance and results obtained in the Saber 11 examination.

# %% [markdown]
# #### student_info

# %%
df_student_info = df_saber11[["estu_agregado",
                            "estu_consecutivo",
                            "estu_dedicacioninternet",
                            "estu_dedicacionlecturadiaria",
                            "estu_depto_reside",
                            "estu_discapacidad",
                            "estu_estudiante",
                            "estu_etnia",
                            "estu_fechanacimiento",
                            "estu_generacione",
                            "estu_genero",
                            "estu_grado",
                            "estu_grupoetnia",
                            "estu_horassemanatrabaja",
                            "estu_nacionalidad",
                            "estu_pilopaga",
                            "estu_privado_libertad",
                            "estu_repite",
                            "estu_tieneetnia",
                            "estu_tipodocumento",
                            "estu_tiporemuneracion",
                            "estu_cod_reside_depto",
                            "estu_cod_reside_mcpio",
                            "estu_mcpio_reside",
                            "estu_pais_reside"
]]

# %%
df_student_info
# Out:
#         estu_agregado  estu_consecutivo estu_dedicacioninternet  \
# 0                   S  SB11201510000485                     NaN
# 1                   S  SB11201510115564                     NaN
# 2                   S  SB11201510097089                     NaN
# 3                   S  SB11201510115560                     NaN
# 4                   S  SB11201510002784                     NaN
# ...               ...               ...                     ...
# 6630103             S  SB11202430031940       Entre 1 y 3 horas
# 6630104             S  SB11202430002696       Entre 1 y 3 horas
# 6630105             S  SB11202430070974       Entre 1 y 3 horas
# 6630106             S  SB11202430586516          Más de 3 horas
# 6630107             S  SB11202430450964   Entre 30 y 60 minutos
#
#         estu_dedicacionlecturadiaria estu_depto_reside estu_discapacidad  \
# 0                                NaN            BOGOTA               NaN
# ...

# %% [markdown]
# #### school_info

# %%
df_stunder_result = df_saber11[["estu_consecutivo",
                            "cole_cod_dane_establecimiento",
                            "cole_cod_dane_sede",
                            "desemp_c_naturales",
                            "desemp_ingles",
                            "desemp_lectura_critica",
                            "desemp_matematicas",
                            "desemp_sociales_ciudadanas",
                            "estu_cod_depto_presentacion",
                            "estu_cod_mcpio_presentacion",
                            "estu_depto_presentacion",
                            "estu_mcpio_presentacion",
                            "percentil_c_naturales",
                            "percentil_global",
                            "percentil_ingles",
                            "percentil_lectura_critica",
                            "percentil_matematicas",
                            "percentil_sociales_ciudadanas",
                            "periodo",
                            "punt_c_naturales",
                            "punt_global",
                            "punt_ingles",
                            "punt_lectura_critica",
                            "punt_matematicas",
                            "punt_sociales_ciudadanas"
]]

# %%
df_stunder_result
# Out:
#          estu_consecutivo  cole_cod_dane_establecimiento  cole_cod_dane_sede  \
# 0        SB11201510000485                   3.117690e+11        3.117690e+11
# 1        SB11201510115564                   3.762500e+11        3.762500e+11
# 2        SB11201510097089                   3.110011e+11        3.110011e+11
# 3        SB11201510115560                   3.762500e+11        3.762500e+11
# 4        SB11201510002784                   3.080010e+11        3.080010e+11
# ...                   ...                            ...                 ...
# 6630103  SB11202430031940                   1.110010e+11        1.110010e+11
# 6630104  SB11202430002696                   3.200010e+11        3.200010e+11
# 6630105  SB11202430070974                   1.765200e+11        1.765208e+11
# 6630106  SB11202430586516                   3.050010e+11        3.050010e+11
# 6630107  SB11202430450964                   1.410010e+11        1.410010e+11
#
# ...

# %% [markdown]
# #### socioeconomic_info

# %%
df
estu_consecutivo
estu_inse_individual
estu_nse_individual
fami_comecarnepescadohuevo
fami_comecerealfrutoslegumbre
fami_comelechederivados
fami_cuartoshogar
fami_educacionmadre
fami_educacionpadre
fami_estratovivienda
fami_numhermanos
fami_numlibros
fami_personashogar
fami_situacioneconomica
fami_tieneautomovil
fami_tienecomputador
fami_tieneconsolavideojuegos
fami_tienehornomicroogas
fami_tieneinternet
fami_tienelavadora
fami_tienemotocicleta
fami_tieneserviciotv
fami_trabajolabormadre
fami_trabajolaborpadre
