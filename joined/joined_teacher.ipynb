# %% [markdown]
# # Teacher information - Join
#     - Author: Santiago Avella. Git hub: https://github.com/TiagoMimi

# %%
import pandas as pd
from pathlib import Path
import warnings
warnings.filterwarnings("ignore")
# *Configure pandas to display all columns in DataFrame outputs*
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Load the data

# %%
# Current working directory
script_path = Path.cwd()

# Find the project folder
project_path = script_path

while project_path.name != "saber11_db":
    project_path = project_path.parent

# %% [markdown]
# ### 2024

# %%
# The folder containing the TXT files
data_path = project_path / "data" / "source" / "teacher" / "2024"

# List of TXT files
file_list = [
    data_path / "Docentes escalafonados según estatuto docente.csv",
    data_path / "Docentes ocupados en CLEI (con mayor asignación académica).csv",
    data_path / "Docentes ocupados en la sede educativa según escalafón y tipo de vinculación laboral.csv",
    data_path / "Docentes ocupados según carácter por nivel educativo (educación tradicional) con mayor asignación académica.csv",
    data_path / "Docentes por jornada según máximo nivel educativo alcanzado y rangos de edad.csv"
]

# Choose the DataFrame name for each file
df_names = [
    "df_escalafon",
    "df_clei",
    "df_vinculacion",
    "df_nivel_educativo",
    "df_jornada_edad"
]

# Read each CSV separately
dataframes = {}

for name, file in zip(df_names, file_list):
    dataframes[name] = pd.read_csv(file, sep=",")

df_escalafon_2024 = dataframes["df_escalafon"]
df_clei_2024 = dataframes["df_clei"]
df_vinculacion_2024 = dataframes["df_vinculacion"]
df_nivel_educativo_2024 = dataframes["df_nivel_educativo"]
df_jornada_edad_2024 = dataframes["df_jornada_edad"]

# %% [markdown]
# ### 2023

# %%
# The folder containing the TXT files
data_path = project_path / "data" / "source" / "teacher" / "2023"

# List of TXT files
file_list = [
    data_path / "Docentes escalafonados según estatuto docente.csv",
    data_path / "Docentes ocupados en CLEI (con mayor asignación académica).csv",
    data_path / "Docentes ocupados en la sede educativa según escalafón y tipo de vinculación laboral.csv",
    data_path / "Docentes ocupados según carácter por nivel educativo (educación tradicional) con mayor asignación académica.csv",
    data_path / "Docentes por jornada según máximo nivel educativo alcanzado y rangos de edad.csv"
]

# Choose the DataFrame name for each file
df_names = [
    "df_escalafon",
    "df_clei",
    "df_vinculacion",
    "df_nivel_educativo",
    "df_jornada_edad"
]

# Read each CSV separately
dataframes = {}

for name, file in zip(df_names, file_list):
    dataframes[name] = pd.read_csv(file, 
                                sep=",",
                                encoding="latin-1")

df_escalafon_2023 = dataframes["df_escalafon"]
df_clei_2023 = dataframes["df_clei"]
df_vinculacion_2023 = dataframes["df_vinculacion"]
df_nivel_educativo_2023 = dataframes["df_nivel_educativo"]
df_jornada_edad_2023 = dataframes["df_jornada_edad"]

# %% [markdown]
# ### 2022

# %%
# The folder containing the TXT files
data_path = project_path / "data" / "source" / "teacher" / "2022"

# List of TXT files
file_list = [
    data_path / "Docentes escalafonados según estatuto docente.csv",
    data_path / "Docentes ocupados en CLEI (con mayor asignación académica).csv",
    data_path / "Docentes ocupados en la sede educativa según escalafón y tipo de vinculación laboral.csv",
    data_path / "Docentes ocupados según carácter por nivel educativo (educación tradicional) con mayor asignación académica.csv",
    data_path / "Docentes por jornada según máximo nivel educativo alcanzado y rangos de edad.csv"
]

# Choose the DataFrame name for each file
df_names = [
    "df_escalafon",
    "df_clei",
    "df_vinculacion",
    "df_nivel_educativo",
    "df_jornada_edad"
]

# Read each CSV separately
dataframes = {}

for name, file in zip(df_names, file_list):
    dataframes[name] = pd.read_csv(file, 
                                sep=",",
                                encoding="latin-1")

df_escalafon_2022 = dataframes["df_escalafon"]
df_clei_2022 = dataframes["df_clei"]
df_vinculacion_2022 = dataframes["df_vinculacion"]
df_nivel_educativo_2022 = dataframes["df_nivel_educativo"]
df_jornada_edad_2022 = dataframes["df_jornada_edad"]

# %% [markdown]
# ### 2021

# %%
# The folder containing the TXT files
data_path = project_path / "data" / "source" / "teacher" / "2021"

# List of TXT files
file_list = [
    data_path / "Docentes escalafonados según estatuto docente.csv",
    data_path / "Docentes ocupados en CLEI (mayor asignación académica).csv",
    data_path / "Docentes ocupados en la sede educativa según escalafón y tipo de vinculación laboral.csv",
    data_path / "Docentes ocupados según carácter por nivel educativo (educación tradicional) con mayor asignación académica.csv",
    data_path / "Máximo nivel educativo alcanzado por los docente según rangos de edad por jornada.csv",
    data_path / "Máximo nivel educativo alcanzado por los docentes según rangos de edad por nivel educativo.csv"
]

# Choose the DataFrame name for each file
df_names = [
    "df_escalafon",
    "df_clei",
    "df_vinculacion",
    "df_asignacion_academica",
    "df_nivel_educativo",
    "df_jornada_edad"
]

# Read each CSV separately
dataframes = {}

for name, file in zip(df_names, file_list):
    dataframes[name] = pd.read_csv(file, 
                                sep=",",
                                encoding="latin-1")

df_escalafon_2021 = dataframes["df_escalafon"]
df_clei_2021 = dataframes["df_clei"]
df_vinculacion_2021 = dataframes["df_vinculacion"]
df_nivel_educativo_2021 = dataframes["df_nivel_educativo"]
df_asignacion_academica_2021 = dataframes["df_asignacion_academica"]
df_jornada_edad_2021 = dataframes["df_jornada_edad"]

# %% [markdown]
# ### 2020

# %%
# The folder containing the TXT files
data_path = project_path / "data" / "source" / "teacher" / "2020"

# List of TXT files
file_list = [
    data_path / "Docentes escalafonados según estatuto docente.csv",
    data_path / "Docentes ocupados en CLEI (mayor asignación académica).csv",
    data_path / "Docentes ocupados en la sede educativa según escalafón y tipo de vinculación laboral.csv",
    data_path / "Docentes ocupados según carácter por nivel educativo (educación tradicional) con mayor asignación académica.csv",
    data_path / "Máximo nivel educativo alcanzado por los docente según rangos de edad por jornada.csv",
    data_path / "Máximo nivel educativo alcanzado por los docentes según rangos de edad por nivel educativo.csv"
]

# Choose the DataFrame name for each file
df_names = [
    "df_escalafon",
    "df_clei",
    "df_vinculacion",
    "df_asignacion_academica",
    "df_nivel_educativo",
    "df_jornada_edad"
]
# Read each CSV separately
dataframes = {}

for name, file in zip(df_names, file_list):
    dataframes[name] = pd.read_csv(file, 
                                sep=";")

df_escalafon_2020 = dataframes["df_escalafon"]
df_clei_2020 = dataframes["df_clei"]
df_vinculacion_2020 = dataframes["df_vinculacion"]
df_nivel_educativo_2020 = dataframes["df_nivel_educativo"]
df_asignacion_academica_2020 = dataframes["df_asignacion_academica"]
df_jornada_edad_2020 = dataframes["df_jornada_edad"]

# %% [markdown]
# ### 2019

# %%
# The folder containing the TXT files
data_path = project_path / "data" / "source" / "teacher" / "2019"

# List of TXT files
file_list = [
    data_path / "Docentes escalafonados según estatuto docente.csv",
    data_path / "Docentes ocupados en CLEI (mayor asignación académica).csv",
    data_path / "Docentes ocupados en la sede educativa según escalafón y tipo de vinculación laboral.csv",
    data_path / "Docentes ocupados según carácter por nivel educativo (educación tradicional) con mayor asignación académica.csv",
    data_path / "Máximo nivel educativo alcanzado por los docente según rangos de edad por jornada.csv",
    data_path / "Máximo nivel educativo alcanzado por los docentes según rangos de edad por nivel educativo.csv"
]

# Choose the DataFrame name for each file
df_names = [
    "df_escalafon",
    "df_clei",
    "df_vinculacion",
    "df_asignacion_academica",
    "df_nivel_educativo",
    "df_jornada_edad"
]
# Read each CSV separately
dataframes = {}

for name, file in zip(df_names, file_list):
    dataframes[name] = pd.read_csv(file, 
                                sep=";")

df_escalafon_2019 = dataframes["df_escalafon"]
df_clei_2019 = dataframes["df_clei"]
df_vinculacion_2019 = dataframes["df_vinculacion"]
df_nivel_educativo_2019 = dataframes["df_nivel_educativo"]
df_asignacion_academica_2019 = dataframes["df_asignacion_academica"]
df_jornada_edad_2019 = dataframes["df_jornada_edad"]

# %% [markdown]
# ### 2018

# %%
# The folder containing the TXT files
data_path = project_path / "data" / "source" / "teacher" / "2018"

# List of TXT files
file_list = [
    data_path / "Docentes escalafonados según estatuto docente.csv",
    data_path / "Docentes ocupados en CLEI (mayor asignación académica).csv",
    data_path / "Docentes ocupados en la sede educativa según escalafón y tipo de vinculación laboral.csv",
    data_path / "Docentes ocupados según carácter por nivel educativo (educación tradicional) con mayor asignación académica.csv",
    data_path / "Máximo nivel educativo alcanzado por los docente según rangos de edad por jornada.csv",
    data_path / "Máximo nivel educativo alcanzado por los docentes según rangos de edad por nivel educativo.csv"
]

# Choose the DataFrame name for each file
df_names = [
    "df_escalafon",
    "df_clei",
    "df_vinculacion",
    "df_asignacion_academica",
    "df_nivel_educativo",
    "df_jornada_edad"
]

# Read each CSV separately
dataframes = {}

for name, file in zip(df_names, file_list):
    dataframes[name] = pd.read_csv(file, 
                                sep=",",
                                encoding="latin-1")

df_escalafon_2018 = dataframes["df_escalafon"]
df_clei_2018 = dataframes["df_clei"]
df_vinculacion_2018 = dataframes["df_vinculacion"]
df_nivel_educativo_2018 = dataframes["df_nivel_educativo"]
df_asignacion_academica_2018 = dataframes["df_asignacion_academica"]
df_jornada_edad_2018 = dataframes["df_jornada_edad"]

# %% [markdown]
# ### 2017

# %%
# The folder containing the TXT files
data_path = project_path / "data" / "source" / "teacher" / "2017"

# List of TXT files
file_list = [
    data_path / "Docentes escalafonados según estatuto docente.csv",
    data_path / "Docentes ocupados en CLEI (mayor asignación académica).csv",
    data_path / "Docentes ocupados en la sede educativa según escalafón y tipo de vinculación laboral.csv",
    data_path / "Docentes ocupados según carácter por nivel educativo (educación tradicional) con mayor asignación académica.csv",
    data_path / "Último nivel educativo alcanzado por los docentes según rangos de edad por nivel educativo.txt",
    data_path / "Último nivel educativo alcanzado por los docente según rangos de edad por jornada.csv"
]

# Choose the DataFrame name for each file
df_names = [
    "df_escalafon",
    "df_clei",
    "df_vinculacion",
    "df_asignacion_academica",
    "df_nivel_educativo",
    "df_jornada_edad"
]

# Read each CSV separately
dataframes = {}

for name, file in zip(df_names, file_list):
    dataframes[name] = pd.read_csv(file, 
                                sep=";",
                                encoding="latin-1")

df_escalafon_2017 = dataframes["df_escalafon"]
df_clei_2017 = dataframes["df_clei"]
df_vinculacion_2017 = dataframes["df_vinculacion"]
df_nivel_educativo_2017 = dataframes["df_nivel_educativo"]
df_asignacion_academica_2017 = dataframes["df_asignacion_academica"]
df_jornada_edad_2017 = dataframes["df_jornada_edad"]

# %%
df_escalafon_2017 = df_escalafon_2017.rename(columns={"ï»¿SEDE_CODIGO":"SEDE_CODIGO"})
df_clei_2017 = df_clei_2017.rename(columns={"ï»¿SEDE_CODIGO":"SEDE_CODIGO"})
df_vinculacion_2017 = df_vinculacion_2017.rename(columns={"ï»¿SEDE_CODIGO":"SEDE_CODIGO"})

# %% [markdown]
# ### 2016

# %%
# The folder containing the TXT files
data_path = project_path / "data" / "source" / "teacher" / "2016"

# List of TXT files
file_list = [
    data_path / "Docentes escalafonados según estatuto docente.txt",
    data_path / "Docentes ocupados en CLEI (mayor asignación académica).txt",
    data_path / "Docentes ocupados en la sede educativa según escalafón y tipo de vinculación laboral.txt",
    data_path / "Docentes ocupados, según carácter, por nivel educativo (educación tradicional) donde tiene la mayor asignación académica.txt",
    data_path / "Último nivel educativo alcanzado por el docente,  nivel educativo donde tiene la mayor asignación académica y rango de edad del docente por jornada.txt",
    data_path / "Último nivel educativo alcanzado por los docentes  con asignación académica y edad del docente.txt"]

# Choose the DataFrame name for each file
df_names = [
    "df_escalafon",
    "df_clei",
    "df_vinculacion",
    "df_asignacion_academica",
    "df_nivel_educativo",
    "df_jornada_edad"
]

# Read each TXT separately
dataframes = {}

for name, file in zip(df_names, file_list):
    dataframes[name] = pd.read_csv(
        file,
        sep="\t",
        encoding="latin-1"
    )

# Assign DataFrames
df_escalafon_2016 = dataframes["df_escalafon"]
df_clei_2016 = dataframes["df_clei"]
df_vinculacion_2016 = dataframes["df_vinculacion"]
df_asignacion_academica_2016 = dataframes["df_asignacion_academica"]
df_nivel_educativo_2016 = dataframes["df_nivel_educativo"]
df_jornada_edad_2016 = dataframes["df_jornada_edad"]

# %% [markdown]
# ### 2015

# %%
# The folder containing the TXT files
data_path = project_path / "data" / "source" / "teacher" / "2015"

# List of TXT files
file_list = [
    data_path / "Docentes escalafonados según estatuto docente.csv",
    data_path / "Docentes ocupados según cáracter, para niveles de enseñanza CLEI y Otros Modelos.csv",
    data_path / "Docentes ocupados en la sede educativa.csv",
    data_path / "Docentes ocupados según cáracter,para los niveles de enseñanza prees, pri,seca y med.csv",
    data_path / "útimo nivel educativo alcanzado por el docente.csv",
    data_path / "Informacion general de docentes por jornada.csv"
]

# Choose the DataFrame name for each file
df_names = [
    "df_escalafon",
    "df_clei",
    "df_vinculacion",
    "df_asignacion_academica",
    "df_nivel_educativo",
    "df_jornada_edad"
]

# Read each CSV separately
dataframes = {}

for name, file in zip(df_names, file_list):
    dataframes[name] = pd.read_csv(file, 
                                sep=",",
                                encoding="latin-1")

df_escalafon_2015 = dataframes["df_escalafon"]
df_clei_2015 = dataframes["df_clei"]
df_vinculacion_2015 = dataframes["df_vinculacion"]
df_nivel_educativo_2015 = dataframes["df_nivel_educativo"]
df_asignacion_academica_2015 = dataframes["df_asignacion_academica"]
df_jornada_edad_2015 = dataframes["df_jornada_edad"]

# %% [markdown]
# ## Concat

# %% [markdown]
# #### Escalafon

# %%
df_escalafon = pd.concat([df_escalafon_2015,
                        df_escalafon_2016,
                        df_escalafon_2017,
                        df_escalafon_2018,
                        df_escalafon_2019,
                        df_escalafon_2020,
                        df_escalafon_2021,
                        df_escalafon_2022,
                        df_escalafon_2023,
                        df_escalafon_2024], axis=0)

# %%
df_escalafon
# Out:
#          SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  GRADOESCA_ID GRADOESCA_CODIGO  \
# 0       308758001975           2          2015             9                7
# 1       308758076142           2          2015            15               13
# 2       283094000442           2          2015            14               12
# 3       315238001464           2          2015            22            2A_SE
# 4       308758001975           2          2015             6                4
# ...              ...         ...           ...           ...              ...
# 133491  325269004131          11          2024             9                7
# 133492  273686000211          11          2024            16               14
# 133493  227615061063          11          2024            22            2A_SE
# 133494  252250000242          11          2024            16               14
# 133495  252250000242          11          2024            22            2A_SE
#
# ...

# %% [markdown]
# #### Clei

# %%
df_clei = pd.concat([df_clei_2015,
                        df_clei_2016,
                        df_clei_2017,
                        df_clei_2018,
                        df_clei_2019,
                        df_clei_2020,
                        df_clei_2021,
                        df_clei_2022,
                        df_clei_2023,
                        df_clei_2024], axis=0)

# %%
df_clei
# Out:
#        SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  NIVELENSE_ID  NIVELENSE_CODIGO  \
# 0     341298000034           2          2015             5                 5
# 1     386568061022           2          2015             5                 5
# 2     168547000551           2          2015             6                 6
# 3     311001109389           2          2015             5                 5
# 4     308001001676           2          2015             5                 5
# ...            ...         ...           ...           ...               ...
# 2013  444001003793          11          2024             5                 5
# 2014  350001007093          11          2024             5                 5
# 2015  311001108684          11          2024             5                 5
# 2016  141001005203          11          2024             5                 5
# 2017  325307800001          11          2024             5                 5
#
# ...

# %% [markdown]
# #### Vinculacion

# %%
df_vinculacion = pd.concat([df_vinculacion_2015,
                        df_vinculacion_2016,
                        df_vinculacion_2017,
                        df_vinculacion_2018,
                        df_vinculacion_2019,
                        df_vinculacion_2020,
                        df_vinculacion_2021,
                        df_vinculacion_2022,
                        df_vinculacion_2023,
                        df_vinculacion_2024], axis=0)

# %%
df_vinculacion
# Out:
#         SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  VINCULA_ID  VINCULA_CODIGO  \
# 0      285001001340           2          2015           1               1
# 1      285001001340           2          2015           2               2
# 2      250223000203           2          2015           1               1
# 3      268101000781           2          2015           1               1
# 4      268101000781           2          2015           2               2
# ...             ...         ...           ...         ...             ...
# 62278  244560000975          11          2024           3               3
# 62279  244560000975          11          2024           1               1
# 62280  413140000259          11          2024           1               1
# 62281  413140000259          11          2024           2               2
# 62282  254001003196          11          2024           1               1
#
#                                           VINCULA_NOMBRE  \
# ...

# %% [markdown]
# #### Asignacion academica

# %%
df_asignacion_academica_2015
# Out:
#          SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  CARACTER_ID  CARACTER_CODIGO  \
# 0       250287000223           2          2015            1                1
# 1       244001002747           2          2015            1                1
# 2       244001002747           2          2015            1                1
# 3       244560003362           2          2015            1                1
# 4       244560003362           2          2015            1                1
# ...              ...         ...           ...          ...              ...
# 187761  376364002343           2          2015            1                1
# 187762  376364002343           2          2015            1                1
# 187763  215176000658           2          2015            1                1
# 187764  286571004764           2          2015            1                1
# 187765  225572000500           2          2015            1                1
#
# ...

# %%
df_asignacion_academica_2016
# Out:
#          SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  CARACTER_ID  CARACTER_CODIGO  \
# 0       268468000604           3          2016            1                1
# 1       368001006841           3          2016            1                1
# 2       205819000060           3          2016            1                1
# 3       205819000060           3          2016            1                1
# 4       368001006841           3          2016            1                1
# ...              ...         ...           ...          ...              ...
# 191832  173001005351           3          2016            1                1
# 191833  173001005351           3          2016            1                1
# 191834  173001005351           3          2016            1                1
# 191835  173001005351           3          2016            2                2
# 191836  291263000181           3          2016            1                1
#
# ...

# %%
df_asignacion_academica_2017
# Out:
#         ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  CARACTER_ID  \
# 0         199001001681           4          2017            1
# 1         199001001681           4          2017            1
# 2         199001001681           4          2017            1
# 3         199001001681           4          2017            1
# 4         199001001681           4          2017            1
# ...                ...         ...           ...          ...
# 236627    354518001139           4          2017            1
# 236628    354518001139           4          2017            1
# 236629    354518001139           4          2017            1
# 236630    354518001139           4          2017            1
# 236631    223555001877           4          2017            1
#
#         CARACTER_CODIGO CARACTER_NOMBRE  NIVELENSE_ID  NIVELENSE_CODIGO  \
# 0                     1      AcadÃ©mico             2                 2
# 1                     1      AcadÃ©mico             2                 2
# ...

# %%
df_asignacion_academica_2018
# Out:
#          SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  CARACTER_ID  CARACTER_CODIGO  \
# 0       141349000108           5          2018            1                1
# 1       141349000108           5          2018            1                1
# 2       141349000108           5          2018            1                1
# 3       141349000108           5          2018            1                1
# 4       141349000108           5          2018            1                1
# ...              ...         ...           ...          ...              ...
# 216205  252696000955           5          2018            1                1
# 216206  219418001579           5          2018            1                1
# 216207  219418001579           5          2018            1                1
# 216208  281065003081           5          2018            1                1
# 216209  276126000451           5          2018            1                1
#
# ...

# %%
df_asignacion_academica_2019
# Out:
#          SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  CARACTER_ID  CARACTER_CODIGO  \
# 0       311001109028           6          2019            1                1
# 1       311001109028           6          2019            1                1
# 2       311001109028           6          2019            1                1
# 3       311001109028           6          2019            1                1
# 4       311001109028           6          2019            1                1
# ...              ...         ...           ...          ...              ...
# 219307  125473000137           6          2019            1                1
# 219308  125473000137           6          2019            1                1
# 219309  125473000137           6          2019            1                1
# 219310  125473000137           6          2019            1                1
# 219311  125473000137           6          2019            2                2
#
# ...

# %%
df_asignacion_academica_2020
# Out:
#          SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  CARACTER_ID  CARACTER_CODIGO  \
# 0       273067001881           7          2020            1                1
# 1       105360000121           7          2020            1                1
# 2       163130000149           7          2020            1                1
# 3       163130000149           7          2020            1                1
# 4       205315000042           7          2020            1                1
# ...              ...         ...           ...          ...              ...
# 219719  219701000376           7          2020            1                1
# 219720  291407000204           7          2020            1                1
# 219721  291407000204           7          2020            1                1
# 219722  291798000025           7          2020            1                1
# 219723  291798000025           7          2020            1                1
#
# ...

# %%
df_asignacion_academica_2021
# Out:
#          SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  CARACTER_ID  CARACTER_CODIGO  \
# 0       154001008967           8          2021            1                1
# 1       154001008967           8          2021            1                1
# 2       154001008967           8          2021            1                1
# 3       176275001393           8          2021            1                1
# 4       176275001393           8          2021            1                1
# ...              ...         ...           ...          ...              ...
# 259151  308758004087           8          2021            1                1
# 259152  308758004087           8          2021            1                1
# 259153  308758004087           8          2021            1                1
# 259154  308758004087           8          2021            1                1
# 259155  308758004087           8          2021            1                1
#
# ...

# %%
df_asignacion_academica = pd.concat([df_asignacion_academica_2015,
                        df_asignacion_academica_2016,
                        df_asignacion_academica_2017,
                        df_asignacion_academica_2018,
                        df_asignacion_academica_2019,
                        df_asignacion_academica_2020,
                        df_asignacion_academica_2021,
                        df_asignacion_academica_2022,
                        df_asignacion_academica_2023,
                        df_asignacion_academica_2024], axis=0)

# %% [markdown]
# #### Nivel educativo

# %%
df_nivel_educativo_2015
# Out:
#          SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  NIVELENSE_ID  \
# 0       347555027974           2          2015             1
# 1       347555027974           2          2015             2
# 2       347555027974           2          2015             3
# 3       347555027974           2          2015             1
# 4       347555027974           2          2015             3
# ...              ...         ...           ...           ...
# 147052  376364002033           2          2015             1
# 147053  376364002033           2          2015             1
# 147054  450568001481           2          2015             2
# 147055  976001000125           2          2015             1
# 147056  976001000125           2          2015             1
#
#         NIVELENSE_CODIGO   NIVELENSE_NOMBRE  NIVELEDUCDOC_ID  \
# 0                      1         Preescolar                7
# 1                      2    Básica primaria                7
# ...

# %%
df_nivel_educativo_2016
# Out:
#          SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  JORNADA_ID  JORNADA_CODIGO  \
# 0       205034000361           3          2016           1               1
# 1       268327000023           3          2016           2               2
# 2       268327000074           3          2016           2               2
# 3       268468000469           3          2016           1               1
# 4       268468000124           3          2016           1               1
# ...              ...         ...           ...         ...             ...
# 207500  227025080682           3          2016           2               2
# 207501  227075000574           3          2016           2               2
# 207502  273236000121           3          2016           2               2
# 207503  283592001782           3          2016           2               2
# 207504  218592000470           3          2016           2               2
#
#        JORNADA_NOMBRE  NIVELEDUCDOC_ID  NIVELEDUCDOC_CODIGO  \
# ...

# %% [markdown]
# #### edad
